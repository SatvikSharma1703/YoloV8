# %%
# !nvidia-smi
# Out:
# Thu Jul  6 12:23:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# **Installing Ultralytics for V8**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 11.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Connecting drive with Notebook**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks
# Out:
# /content/drive/MyDrive/Colab_Notebooks

# %%
# !ls
# Out:
# data  data.yaml  Dogs  YoloV8.ipynb  yolov8m.pt  yolov8n.pt  yolov8s.pt

# %%
# !ls
# Out:
# data  data.yaml  Dogs  YoloV8.ipynb  yolov8m.pt  yolov8n.pt  yolov8s.pt

# %% [markdown]
# **TRAIN THE MODEL**

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=100 plots=true imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **VALIDATE THE MODEL**

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/Colab_Notebooks/bags/valid/labels.cache... 39 images, 0 backgrounds, 0 corrupt: 100% 39/39 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.29it/s]
#                    all         39         39      0.969       0.98      0.978      0.871
#                 cheque         39         14      0.979          1      0.995      0.913
#            cashier bag         39         25      0.959       0.96      0.961      0.829
# Speed: 6.0ms preprocess, 28.9ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# **Testing The Model**

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=bags/test/images
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# image 1/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_10.jpg: 640x576 1 cashier bag, 68.1ms
# image 2/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_100.jpg: 640x640 (no detections), 37.9ms
# image 3/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_11.jpg: 640x416 1 cashier bag, 68.9ms
# image 4/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_15.jpg: 640x384 1 cashier bag, 68.5ms
# image 5/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_21.jpg: 640x448 1 cashier bag, 66.7ms
# image 6/39 /content/drive/MyDrive/Colab_Notebooks/bags/test/images/bank deposit bags_24.jpg: 640x384 2 cashier bags, 26.0ms
# ...
